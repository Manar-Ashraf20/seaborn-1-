# %% [markdown]
# # seaborn

# %% [markdown]
# ##### data

# %%
from IPython.display import Image, display
from pathlib import Path
img_path = Path(r'C:\Users\Connect\Pictures\Screenshot 2025-07-02 184753.png')
display(Image(filename=str(img_path), width=600))

# %%
from IPython.display import Image, display
from pathlib import Path
img_path = Path(r'C:\Users\Connect\Pictures\Screenshot 2025-07-03 130743.png')
display(Image(filename=str(img_path), width=600))

# %% [markdown]
# Seaborn =>  is a powerful Python library for creating data visualizations
#         =>  create the most common types of plots

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Tips data set

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x="tip", y="total_bill",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # count plot

# %% [markdown]
# Count plots => take in a categorical list and return bars that represent the number of list entries per category

# %%
sns.countplot(x="day",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [raw]
# Tidy data" means that each observation has its own row and each variable has its own column.
# كل متغير ليه عمود
# كل ملاحظة ليها صف

# %% [markdown]
# ### Adding a third variable with hue parameter

# %% [markdown]
# ##### 1) A scatter plot with hue

# %%
sns.scatterplot(x="tip", y="total_bill",data=tips, hue = "smoker")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ##### Setting hue order using => "hue_order" parameter

# %%
sns.scatterplot(x="total_bill", y="tip",data=tips, hue = "smoker", hue_order=["Yes","No"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##### Specifying hue colors using => palette parameter (take dictionary)

# %%
hue_colors={"Yes":"black",
            "No":"red"}
sns.scatterplot(x="total_bill",
                y="tip",
                data=tips,
                hue="smoker",
                palette=hue_colors)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##### Color options

# %%
from IPython.display import Image, display
from pathlib import Path
img_path = Path(r'C:\Users\Connect\Pictures\Screenshot 2025-07-02 191325.png')
display(Image(filename=str(img_path), width=600))

# %% [markdown]
# #####  Using hue with count plots

# %%
sns.countplot(x="smoker",
              data=tips,
              hue="sex")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# # relplot function() & ScatterPlot

# %% [markdown]
# relplot function() =>  visualize the relationship between two quantitative variables using either scatter plots or line plots.

# %% [markdown]
# #####  scatterplot() using  relplot()

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter")

# %% [markdown]
# ##### Subplots in columns  => using 'col' parameter

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           col="smoker")

# %% [markdown]
# ##### subplots in rows ===> using 'row' parameter

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           row="smoker")

# %% [markdown]
# ##### Subplots in rows and columns

# %% [markdown]
# فى حالة انى هضيف متغيرين اضافين

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           col="smoker",
           row="time")

# %% [markdown]
# ##### Wrapping columns (تحديد عدد ال subplots فى كل صف)
# فى حالة ان القيم كتيرة فى الصف الواحد

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           col="day")

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           col="day",
           col_wrap=2)

# %% [markdown]
# ###### Ordering columns

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           col="day",
           col_wrap=2,
           col_order=["Thur","Fri","Sat","Sun"])

# %% [markdown]
# ### Customizing scatter plots

# %% [markdown]
# ##### Subgroups with point size  => using 'size' parameter

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           size="size")

# %% [markdown]
# ##### Point size and hue ==>   using "hue" & "size" parameter

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           size="size",
           hue="size")

# %% [markdown]
# ##### Subgroups with point style ===> using "style" parameter

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           hue="smoker",
           style="smoker")

# %% [markdown]
# ##### Changing point transparency ===> using "alpha" parameter range(0,1)

# %%
sns.relplot(x="total_bill",
            y="tip",
            data=tips,
            kind="scatter",
           alpha=0.4)

# %% [markdown]
# # line plots

# %% [markdown]
# ### create line plot

# %%
sns.relplot(x="tip",
            y="total_bill",
            data=tips,
            kind="line")

# %% [markdown]
# ### Subgroups  ==> using "hue"&"style" parameters

# %%
sns.relplot(x="tip",
            y="total_bill",
            data=tips,
            kind="line",
           hue="time",
           style="time")

# %% [markdown]
# ### Adding markers ==> using markers parameter equal to True

# %%
sns.relplot(x="tip",
            y="total_bill",
            data=tips,
            kind="line",
           hue="time",
           style="time",
           markers=True)

# %% [markdown]
# ### Turning off line style ==> using "dashes" parameter equal to False

# %%
sns.relplot(x="tip",
            y="total_bill",
            data=tips,
            kind="line",
           hue="time",
           style="time",
           markers=True,
           dashes=False)

# %% [markdown]
# ### Multiple observations per x-value

# %% [markdown]
# إذا كان هناك عدة نقاط بيانات لنفس قيمة X
# فسيتم تجميعها في قياس واحد المتوسط

# %% [markdown]
# confidence interval for the mean, displayed by the shaded region

# %%
sns.relplot(x="size",
            y="tip",
            data=tips,
            kind="line")

# %% [markdown]
# #####  Replacing confidence interval with standard deviation ==> by "errorbar" parameter = "sd"

# %%
sns.relplot(x="size",
            y="tip",
            data=tips,
            kind="line",
           errorbar="sd")

# %% [markdown]
# ##### Turning off confidence interval using ==> "errorbar" parameter = None

# %%
sns.relplot(x="size",
            y="tip",
            data=tips,
            kind="line",
           errorbar=None)

# %% [markdown]
# # catplot() & countplot

# %% [markdown]
# ### countplot() using catplot()

# %%
sns.catplot(x="day",
            data=tips,
            kind="count")

# %% [markdown]
# ### Changing the order ==> using "order" parameyer

# %%
category_order=["Sat","Sun","Thur","Fri"]
sns.catplot(x="day",
            data=tips,
            kind="count",
           order=category_order)

# %% [markdown]
# # catplot() &  Bar plot

# %% [markdown]
# ### create Barplot

# %%
sns.catplot(x="day",
            y="total_bill",
            data=tips,
            kind="bar")
plt.show()

# %% [markdown]
# ### Confidence intervals

# %% [markdown]
# lines => show 95% confidence interval for the mean

# %% [markdown]
# ##### Turning off confidence intervals => using "errorbar" parameter =None

# %%
sns.catplot(x="day",
            y="total_bill",
            data=tips,
            kind="bar",
           errorbar=None)
plt.show()

# %% [markdown]
# ###  Changing the orientation => by switching the x and y parameters

# %%
sns.catplot(x="total_bill",
            y="day",
            data=tips,
            kind="bar",
           errorbar=None)
plt.show()

# %% [markdown]
# # Boxplot

# %% [markdown]
#  compare the distribution of quantitative variable across different groups of a categorical variable

# %% [markdown]
#  colored box =>  represents the 25th to 75th percentile
#  line in the middle of the box => represents the median
#  whiskers => give the sence of spread of the distribution
#  floating point => represent outliers

# %% [markdown]
# ### Create a box plot

# %%
sns.catplot(x="time",
            y="total_bill",
            data=tips,
            kind="box")
plt.show()

# %% [markdown]
# ### Changing order of categories using 'order' parameter

# %%
sns.catplot(x="time",y="total_bill",data=tips,kind="box",order=["Dinner","Lunch"])

# %% [markdown]
# ### Omit outliers using 'showfliers' parameter

# %%
g = sns.catplot(
    x="time", 
    y="total_bill", 
    data=tips, 
    kind="box", 
    showfliers=False 
)
plt.show()

# %% [markdown]
# ### IQR & Whiskers

# %% [markdown]
#  IQR => is the 25th to 75th percentile of a distribution
#  whiskers extend to 1.5* the IQR

# %% [markdown]
#  changing it with whis parameter
#  whis=2.0
#  or
#  whis=[5,95] او اى نسبة انتى عاوزها

# %%
sns.catplot(x="time",y="total_bill",data=tips,kind="box",whis=[0,100])
plt.show()

# %%
sns.catplot(x="time",y="total_bill",data=tips,kind="box",whis=[5,95])
plt.show()

# %%
sns.catplot(x="time",y="total_bill",data=tips,kind="box",whis=2)
plt.show()

# %% [markdown]
# # point plot

# %% [markdown]
# show
# - the mean of a quantitative variable for the observation in each category as a point
# - the convitance intervals
# - vertical lines show 95% confidence intervals

# %% [markdown]
# confidance interval in( point plot & line plot & bar plot )

# %% [markdown]
# point plot vs line plot
# both show
#  - mean of quantitative variable
#  - 95% confidence intervals for the mean
# key difference
# (line plot )
#  - relational plots
#    x- and y- axis quantitative variables
# (point plot)
#  - categorical plots
#    one axis (x-axis) => is a categorical variable

# %% [markdown]
# point plot vs. bar plot
# both show
#  - mean of the quantitative variable
#  - 95% confidence intervals for the mean
# when should we use one over the other ??
#  -In point plot it easier to compare the heights of the subgroup points
#  - In the point plot It's also easier to look at the differences in slope

# %% [markdown]
# ### create point plot

# %%
sns.catplot(x="day" , y="total_bill" , data = tips ,kind="point")
plt.show()

# %% [markdown]
# ### Disconnecting the points with join=False parameter or linestyle='none' parameter

# %%
sns.catplot(x="day" , y="total_bill" , data = tips ,kind="point",linestyle='none')
plt.show()

# %% [markdown]
# ### Display the median

# %% [markdown]
# we need to
# 1) import the medium function from numpy library
# 2) set estimator = median

# %%
from numpy import median

# %%
sns.catplot(x="day" , y="total_bill" , data = tips ,kind="point", estimator = median)
plt.show()

# %% [markdown]
# ### Customizing the confidence intervals

# %% [markdown]
# ##### 1) Add caps to the end of  the confidence intervals by 'capsize' parameter

# %%
sns.catplot(x="day" , y="total_bill" , data = tips ,kind="point",capsize=0.2)
plt.show()

# %% [markdown]
# ###### 2) Turning off confidence intervals by 'ci' parameter = None or 'errorbar' parameter

# %%
sns.catplot(x="day" , y="total_bill" , data = tips ,kind="point", errorbar=None)
plt.show()

# %% [markdown]
# # Custoomize plot types

# %% [markdown]
# sns.function()

# %% [markdown]
# ### Changing the figure style using '   .set_style()' function

# %% [markdown]
# 5 styles which change the background & axes of the plot

# %% [markdown]
# 1) white => provides clean axes with a solid white background.
# 2) whitegrid => will add a gray grid in the background.
# 3) ticks =>  similar to "white", but adds small tick marks to the x- and y-axes.
# 4) dark =>  provides a gray background
# 5) darkgrid => provides a gray background with a white grid

# %%
sns.set_style('darkgrid')
sns.catplot(x="day" , y="total_bill" , data = tips ,kind="point")
plt.show()

# %% [markdown]
# ### Changing the palette => using '    hue & legend=False & palette ' parameters

# %% [markdown]
# 1) present palettes
# 2) create a custom palette

# %% [markdown]
# ##### present palettes

# %% [markdown]
# 1) Diverging palettes ( RdBu & RdBu_r     &     PRGn & PRGn_r)
# 2) sequential palettes => single color moving from light to dark
#                        => جيدة للتأكيد على متغير على نطاق مستمر

# %%
sns.catplot(x="day" , data = tips ,kind="count",hue="day",  
    palette='RdBu',
    legend=False)
plt.show()

# %% [markdown]
# ##### palettes list

# %%
print(sns.palettes.SEABORN_PALETTES)
# Out:
# {'deep': ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD'], 'deep6': ['#4C72B0', '#55A868', '#C44E52', '#8172B3', '#CCB974', '#64B5CD'], 'muted': ['#4878D0', '#EE854A', '#6ACC64', '#D65F5F', '#956CB4', '#8C613C', '#DC7EC0', '#797979', '#D5BB67', '#82C6E2'], 'muted6': ['#4878D0', '#6ACC64', '#D65F5F', '#956CB4', '#D5BB67', '#82C6E2'], 'pastel': ['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0'], 'pastel6': ['#A1C9F4', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#FFFEA3', '#B9F2F0'], 'bright': ['#023EFF', '#FF7C00', '#1AC938', '#E8000B', '#8B2BE2', '#9F4800', '#F14CC1', '#A3A3A3', '#FFC400', '#00D7FF'], 'bright6': ['#023EFF', '#1AC938', '#E8000B', '#8B2BE2', '#FFC400', '#00D7FF'], 'dark': ['#001C7F', '#B1400D', '#12711C', '#8C0800', '#591E71', '#592F0D', '#A23582', '#3C3C3C', '#B8850A', '#006374'], 'dark6': ['#001C7F', '#12711C', '#8C0800', '#591E71', '#B8850A', '#006374'], 'c
# ...

# %% [markdown]
# ##### Create a custom palette

# %%
custom_palette=['red','green','orange','blue']
sns.catplot(x="day" ,
            data = tips ,
            kind="count",
            hue="day",  
    palette=custom_palette,
    legend=False)

# %% [markdown]
# ### Change scale of plot '   .set_context() function '

# %% [markdown]
# Scale options from smallest ==> largest
# "paper" , "notebook" , "talk" , "poster"

# %%
sns.set_context("poster")
sns.catplot(x="day" ,
            y="total_bill" ,
            data = tips ,
            kind="bar")
plt.show()

# %%
sns.set_context("paper")
sns.catplot(x="day" ,
            y="total_bill" ,
            data = tips ,
            kind="bar")
plt.show()

# %% [markdown]
# ### Adding title and labels

# %% [markdown]
# ##### comparison between FaceGride vs. AxesSubplot object

# %%
from IPython.display import Image, display
from pathlib import Path
img_path = Path(r'C:\Users\Connect\Pictures\Screenshot 2025-07-02 152236.png')
display(Image(filename=str(img_path), width=600))

# %% [markdown]
# ##### Add a title to a FacetGrid object

# %% [markdown]
# 1) assign the plot to the variable "g".
# 2) set the title using "g.fig.suptitle()"

# %%
g=sns.catplot(x="time",
              y="total_bill",
              data=tips,
              kind="box")
g.fig.suptitle("new title")
plt.show()

# %% [markdown]
# ##### Adjusting height of title in FacetGrid => using the "y" parameter.

# %%
g=sns.catplot(x="time",y="total_bill",data=tips,kind="box")
g.fig.suptitle("new title",y=0.9)
plt.show()

# %% [markdown]
# ##### Adding a title to AxesSubplot & ( Adjusting height of title using "y" parameter)

# %% [markdown]
# 1) assign the plot to the variable "g"
# 2) set the title using "g.set_title()"

# %%
g=sns.boxplot(x="time",y="total_bill",data=tips)
g.set_title("new title",y=0.9)
plt.show()

# %% [markdown]
# ##### Titles for subplots

# %% [markdown]
# 1) using "g.fig.suptitle()"
#               => to add a title to the figure as a whole      (FacetGrid object)
# 2) g.set_titles()"
#               =>  to set the titles for each AxesSubplot.
#     (If you want to use the variable name in the title,
#         you can use "col_name" in {} to reference the column value)

# %%
g=sns.catplot(x="time",y="total_bill",data=tips,kind="box",col="sex")
g.fig.suptitle("new title",y=1.03)
g.set_titles(" this is {col_name}")

# %% [markdown]
# ##### Adding axis labels using "set()"  function

# %% [markdown]
# 1) assign plot to a variable
# 2) call "set()" function
# g.set(x_lable=" ",
#       y_lable=" ")

# %%
g=sns.catplot(x="time",
              y="total_bill",
              data=tips,
              kind="box")
g.set(xlabel="new x labl",ylabel="new x labl")

# %% [markdown]
# ##### Rotating x_axis tick labels      ==>  using plt.xticks(rotation=90)

# %%
g=sns.catplot(x="time",
              y="total_bill",
              data=tips,
              kind="box")
plt.xticks(rotation=90)
# Out:
# ([0, 1], [Text(0, 0, 'Lunch'), Text(1, 0, 'Dinner')])
